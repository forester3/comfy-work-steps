# %%
# @title CivitAI-DL
import sys, os, requests
import json
import ipywidgets as widgets
from IPython.display import display, HTML
#import importlib

sys.path.append(os.path.abspath("ImageGenSupporter"))
import manual_url_download as mud
import model_download_list_ids as mid

#importlib.reload(mud)
#importlib.reload(mid)

with open(f"{WORK_STEPS}/civitai_models.json", encoding="utf-8") as f:
    MODEL_DICT = json.load(f)
    
mid.make_downloader_ui(MODEL_DICT, f"{HOME_DIR}/ComfyUI/models")
